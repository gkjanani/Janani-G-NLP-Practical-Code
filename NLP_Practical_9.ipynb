# %%
from textblob import TextBlob

# %%
reviews = []
"i love this product , it is amazing",
"this is the worst purchase i even made.",
"the product is okay , not great"
# Out:
# 'the product is okay , not great'

# %%
from textblob import TextBlob

reviews = [
    "i love this product , it is amazing",
    "this is the worst purchase i even made.",
    "the product is okay , not great"
]

for review in reviews:
  blob = TextBlob(review)
  polarity = blob.sentiment.polarity
  if polarity > 0:
    sentiment = "Positive"
  elif polarity < 0:
    sentiment = "Negative"
  else:
    sentiment = "Neutral"

  print(f"Review: {review}\nsentiment: {sentiment}\npolarity: {polarity}\n")
# Out:
# Review: i love this product , it is amazing
# sentiment: Positive
# polarity: 0.55
#
# Review: this is the worst purchase i even made.
# sentiment: Negative
# polarity: -1.0
#
# Review: the product is okay , not great
# sentiment: Positive
# polarity: 0.04999999999999999
